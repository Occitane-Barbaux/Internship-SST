# %%
import sys,os
print(sys.version)
import numpy as np
import pandas as pd
import xarray as xr
import glob
import subprocess as sub

import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator,FormatStrFormatter,MaxNLocator
import warnings


import sys,os
import numpy as np

print(sys.path)
#import arviz
import NSSEA as ns
import NSSEA.models as nsm
from cmdstanpy import cmdstan_path, set_cmdstan_path



import sys,os

import xarray as xr
import pandas as pd
import numpy as np

import NSSEA as ns
from NSSEA.__tools import matrix_positive_part
from NSSEA.__tools import matrix_squareroot
import scipy.optimize as sco

import re
from itertools import product

from cmdstanpy import CmdStanModel
import logging

import sys,os

import xarray as xr
import pandas as pd
import numpy as np

import NSSEA as ns
import NSSEA.models as nsm
import scipy.stats as sc
from itertools import product
import statsmodels.api as sm


import matplotlib.backends.backend_pdf as mpdf
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.patches as mplpatch
from matplotlib.ticker import MultipleLocator,FormatStrFormatter,MaxNLocator
import matplotlib.colors as mcolors

### Set seed
from datetime import datetime
import random
# datetime object containing current date and time
now = datetime.now() 
# dd/mm/YY H:M:S
dt_string = now.strftime("%m%d%H%M")
print("seed is: "+  dt_string)
print("No error")
# Out:
# 3.12.0 | packaged by conda-forge | (main, Oct  3 2023, 08:43:22) [GCC 12.3.0]
# ['/home/barbauxo/Documents/05_Autres_Activités/2026_02_SST/Preparation', '/home/barbauxo/miniconda3/envs/TestSDFC/lib/python312.zip', '/home/barbauxo/miniconda3/envs/TestSDFC/lib/python3.12', '/home/barbauxo/miniconda3/envs/TestSDFC/lib/python3.12/lib-dynload', '', '/home/barbauxo/miniconda3/envs/TestSDFC/lib/python3.12/site-packages', '/home/barbauxo/Documents/05_Autres_Activités/2023_11_Transfert_Code_Yoann/NSSEA', '/home/barbauxo/Documents/05_Autres_Activités/2023_11_Transfert_Code_Yoann/SDFC-python']
# seed is: 02101145
# No error
